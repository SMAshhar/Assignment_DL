# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %% [markdown]
# # IMPORTING REQUIRED MODULES

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Assignment3_DL
# Out:
# /content/drive/MyDrive/Assignment3_DL

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import models, layers, optimizers

# %%
import pandas as pd
data = pd.read_csv('CarPrice_Assignment.csv')

# %% [markdown]
# # DATA PREPARATION

# %%
data
# Out:
#      car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0         1          3        alfa-romero giulia  ...      21         27  13495.0
# 1         3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 2         2          3       alfa-romero stelvio  ...      21         27  16500.0
# 3         4          2                audi 100ls  ...      24         30  13950.0
# 4         5          2                audi 100ls  ...      18         22  17450.0
# ..      ...        ...                       ...  ...     ...        ...      ...
# 200     199         -2               volvo 264gl  ...      17         22  18420.0
# 201     205         -1               volvo 264gl  ...      19         25  22625.0
# 202     200         -1              volvo diesel  ...      17         22  18950.0
# 203     190          3                 vw dasher  ...      24         29  11595.0
# ...

# %%
data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
np.where(data.applymap(lambda x : x == '' or x == ' '))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
data.shape
# Out:
# (205, 26)

# %%
data1 = data.copy()
data1
# Out:
#      car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0         1          3        alfa-romero giulia  ...      21         27  13495.0
# 1         3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 2         2          3       alfa-romero stelvio  ...      21         27  16500.0
# 3         4          2                audi 100ls  ...      24         30  13950.0
# 4         5          2                audi 100ls  ...      18         22  17450.0
# ..      ...        ...                       ...  ...     ...        ...      ...
# 200     199         -2               volvo 264gl  ...      17         22  18420.0
# 201     205         -1               volvo 264gl  ...      19         25  22625.0
# 202     200         -1              volvo diesel  ...      17         22  18950.0
# 203     190          3                 vw dasher  ...      24         29  11595.0
# ...

# %%
data1.drop(columns=['car_ID'], inplace=True)

# %%
All_targets = data1.price

# %%
All_targets
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    18420.0
# 201    22625.0
# 202    18950.0
# 203    11595.0
# 204     9980.0
# Name: price, Length: 205, dtype: float64

# %%
data1.drop(columns=['price'], inplace= True)

# %%
carCompany = data1['CarName'].str.split(expand=True)[0]
carCompany
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203             vw
# 204             vw
# Name: 0, Length: 205, dtype: object

# %%
data1['carCompany'] = carCompany

# %%
data1
# Out:
#      symboling                   CarName  ... highwaympg   carCompany
# 0            3        alfa-romero giulia  ...         27  alfa-romero
# 1            1  alfa-romero Quadrifoglio  ...         26  alfa-romero
# 2            3       alfa-romero stelvio  ...         27  alfa-romero
# 3            2                audi 100ls  ...         30         audi
# 4            2                audi 100ls  ...         22         audi
# ..         ...                       ...  ...        ...          ...
# 200         -2               volvo 264gl  ...         22        volvo
# 201         -1               volvo 264gl  ...         25        volvo
# 202         -1              volvo diesel  ...         22        volvo
# 203          3                 vw dasher  ...         29           vw
# 204          3                 vw rabbit  ...         29           vw
#
# [205 rows x 25 columns]

# %%
data1.drop(columns=['CarName'], inplace=True)
data1
# Out:
#      symboling fueltype aspiration  ... citympg highwaympg   carCompany
# 0            3      gas        std  ...      21         27  alfa-romero
# 1            1      gas        std  ...      19         26  alfa-romero
# 2            3      gas        std  ...      21         27  alfa-romero
# 3            2      gas        std  ...      24         30         audi
# 4            2      gas        std  ...      18         22         audi
# ..         ...      ...        ...  ...     ...        ...          ...
# 200         -2      gas      turbo  ...      17         22        volvo
# 201         -1      gas      turbo  ...      19         25        volvo
# 202         -1      gas      turbo  ...      17         22        volvo
# 203          3      gas        std  ...      24         29           vw
# 204          3      gas        std  ...      24         29           vw
#
# [205 rows x 24 columns]

# %%
data1.carCompany.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'buick', 'chevrolet', 'dodge',
#        'honda', 'isuzu', 'jaguar', 'maxda', 'mazda', 'mercury',
#        'mitsubishi', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'renault', 'saab', 'subaru', 'toyota', 'vokswagen', 'volkswagen',
#        'volvo', 'vw'], dtype=object)

# %%
data1.carCompany.replace('vokswagen', 'volkswagen', inplace = True)
data1.carCompany.replace('maxda', 'mazda', inplace = True)
data1.carCompany.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'buick', 'chevrolet', 'dodge',
#        'honda', 'isuzu', 'jaguar', 'mazda', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo', 'vw'], dtype=object)

# %%
data1 = pd.get_dummies(data1, columns=['carCompany','symboling','fueltype','aspiration','doornumber','carbody','drivewheel','enginelocation','enginetype','cylindernumber','fuelsystem'])

# %%
data1
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0         88.6      168.8  ...                0                0
# 1         94.5      171.2  ...                0                0
# 2         88.6      168.8  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      104.3      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      104.3      188.8  ...                0                0
# 203       94.5      159.3  ...                0                0
# 204       94.5      165.7  ...                0                0
#
# [205 rows x 80 columns]

# %%
data1.shape
# Out:
# (205, 80)

# %%
np.random.seed(225)
mask1 = np.random.rand(len(data1)) < 0.70
train_data = data1[mask1]
test_data = data1[~mask1]

# %%
train_data.shape, test_data.shape
# Out:
# ((141, 80), (64, 80))

# %%
train_targets = All_targets[mask1]
test_targets = All_targets[~mask1]

# %%
print(len(data1)*0.2)
# Out:
# 41.0

# %% [markdown]
# # NORMALIZING

# %% [markdown]
# Normalizing Data

# %%
mean = train_data.iloc[:,0:13].mean(axis=0)
mean
# Out:
# wheelbase             98.912766
# carlength            174.446099
# carwidth              66.027660
# carheight             53.716312
# curbweight          2560.290780
# enginesize           124.638298
# boreratio              3.352908
# stroke                 3.239255
# compressionratio      10.416454
# horsepower           102.503546
# peakrpm             5108.510638
# citympg               25.184397
# highwaympg            30.645390
# dtype: float64

# %%
stndrd = train_data.iloc[:,0:13].std(axis = 0)
stndrd
# Out:
# wheelbase             6.076840
# carlength            11.857081
# carwidth              2.158508
# carheight             2.420939
# curbweight          500.618953
# enginesize           36.022469
# boreratio             0.278808
# stroke                0.342175
# compressionratio      4.321119
# horsepower           36.853692
# peakrpm             485.649692
# citympg               6.189395
# highwaympg            6.541226
# dtype: float64

# %%
train_data.iloc[:,0:13] -= mean
train_data.iloc[:,0:13] /= stndrd
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= stndrd
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1715: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, v)

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0    -1.697061  -0.476180  ...                0                0
# 1    -0.726161  -0.273769  ...                0                0
# 2    -1.697061  -0.476180  ...                0                0
# 3     0.146003   0.181655  ...                0                0
# 4     0.080179   0.181655  ...                0                0
# ..         ...        ...  ...              ...              ...
# 196   0.886519   1.210576  ...                0                0
# 197   1.676403   1.210576  ...                0                0
# 200   0.886519   1.210576  ...                0                0
# 201   1.676403   1.210576  ...                0                0
# 203  -0.726161  -1.277389  ...                0                0
#
# [141 rows x 80 columns]

# %%
test_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 5     1.133358   1.539494  ...                0                0
# 9     0.146003   0.240692  ...                0                0
# 11    0.376385   0.198523  ...                0                0
# 12    0.376385   0.198523  ...                0                0
# 13    0.376385   0.198523  ...                0                0
# ..         ...        ...  ...              ...              ...
# 191  -0.265396  -0.231600  ...                0                0
# 198   0.886519   1.210576  ...                0                0
# 199   1.676403   1.210576  ...                0                0
# 202   0.886519   1.210576  ...                0                0
# 204  -0.726161  -0.737627  ...                0                0
#
# [64 rows x 80 columns]

# %% [markdown]
# Normalizing Targets/Labels

# %%
mean_trgts = train_targets.mean()
stndrd_trgts =  train_targets.std()
mean_trgts, stndrd_trgts
# Out:
# (12916.167851063828, 7126.340378065906)

# %%
train_targets.describe()
# Out:
# count      141.000000
# mean     12916.167851
# std       7126.340378
# min       5118.000000
# 25%       7898.000000
# 50%      10795.000000
# 75%      16430.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
train_targets -= mean_trgts
train_targets /= stndrd_trgts
test_targets -= mean_trgts
test_targets /= stndrd_trgts
train_targets, test_targets
# Out:
# (0      0.081224
#  1      0.502899
#  2      0.502899
#  3      0.145072
#  4      0.636208
#           ...
#  196    0.430632
#  197    1.202417
#  200    0.772322
#  201    1.362387
#  203   -0.185392
#  Name: price, Length: 141, dtype: float64, 5      0.672692
#  9      0.327494
#  11     0.562537
#  12     1.130150
#  13     1.149094
#           ...
#  191   -0.662495
#  198    0.505004
#  199    1.340637
#  202    0.846694
#  204   -0.412016
#  Name: price, Length: 64, dtype: float64)

# %% [markdown]
# # Building Model

# %%
train_data.shape[1]
# Out:
# 80

# %%
network = models.Sequential()
network.add(layers.Dense(10, activation='relu', input_shape=(80,)))
network.add(layers.Dense(8, activation='relu'))
network.add(layers.Dense(6, activation='relu'))
network.add(layers.Dense(1))
network.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %%
network.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 10)                810
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 54
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 7
# ...
# Total params: 959
# Trainable params: 959
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Applying K4 Method

# %%
test_data.shape
# Out:
# (64, 80)

# %%
k = 4
val_size = len(train_data) // k
all_scores = []
for i in range(k):
  val_data = train_data[i * val_size : (i + 1) * val_size]
  val_targets = train_targets[i * val_size : (i + 1) * val_size]
  partial_train_data = np.concatenate([train_data[:i * val_size], train_data[(i + 1) * val_size:]])
  partial_train_targets = np.concatenate([train_targets[:i * val_size], train_targets[(i + 1) * val_size:]])
  network.fit(partial_train_data, partial_train_targets, epochs = 100, batch_size = 5, verbose=0)
  val_mse, val_mae = network.evaluate(val_data, val_targets, verbose = 0)
  print(val_mse, val_mae)
  all_scores.append(val_mae)
# Out:
# 0.8732365369796753 0.7701115608215332
# 0.28242507576942444 0.3764723837375641
# 0.0629754438996315 0.18795248866081238
# 0.018790271133184433 0.11705566197633743

# %%
all_scores
# Out:
# [0.7701115608215332,
#  0.3764723837375641,
#  0.18795248866081238,
#  0.11705566197633743]

# %%
test_mse, test_mae = network.evaluate(test_data, test_targets)
test_mse, test_mae
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1108 - mae: 0.2428
# (0.11083392798900604, 0.24279463291168213)

# %%
test_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 5     1.133358   1.539494  ...                0                0
# 9     0.146003   0.240692  ...                0                0
# 11    0.376385   0.198523  ...                0                0
# 12    0.376385   0.198523  ...                0                0
# 13    0.376385   0.198523  ...                0                0
# ..         ...        ...  ...              ...              ...
# 191  -0.265396  -0.231600  ...                0                0
# 198   0.886519   1.210576  ...                0                0
# 199   1.676403   1.210576  ...                0                0
# 202   0.886519   1.210576  ...                0                0
# 204  -0.726161  -0.737627  ...                0                0
#
# [64 rows x 80 columns]

# %%
all_predict = network.predict(test_data)

# %%
all_predict[-1] * stndrd_trgts + mean_trgts
# Out:
# array([9475.218], dtype=float32)

# %%
test_targets
# Out:
# 5      0.672692
# 9      0.327494
# 11     0.562537
# 12     1.130150
# 13     1.149094
#          ...
# 191   -0.662495
# 198    0.505004
# 199    1.340637
# 202    0.846694
# 204   -0.412016
# Name: price, Length: 64, dtype: float64

# %%
-0.412016 * stndrd_trgts + mean_trgts
# Out:
# 9980.001593854626
